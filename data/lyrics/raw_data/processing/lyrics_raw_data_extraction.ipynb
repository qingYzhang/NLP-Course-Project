# %%
import pandas as pd
import numpy as np
import sys
import os

# %% [markdown]
# - [1. Cleaning song_lyrics.csv](#1)
# - [2. Genius Lyrics API](#2)

# %% [markdown]
# ### 1. Cleaning song_lyrics.csv <a id='1'></a>

# %%
lyrics = pd.read_csv("./song_lyrics.csv", on_bad_lines='skip', nrows=3508600)
lyrics = lyrics.iloc[:, [0,1,2,6,8]]
lyrics.to_csv("song_lyrics.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 lyrics = pd.read_csv("./song_lyrics.csv", on_bad_lines='skip', nrows=3508600)
#       2 lyrics = lyrics.iloc[:, [0,1,2,6,8]]
#       3 lyrics.to_csv("song_lyrics.csv")
#
# ...

# %%
f20 = int(lyrics.shape[0]*0.2)
first_20 = lyrics.iloc[:f20, :]
first_20.to_csv("sample_lyrics.csv")

# %% [markdown]
# ### 2. Using Genius Lyrics API <a id='2'></a>

# %%
# Replace 'your_token_here' with the token you obtained from Genius
genius = Genius('stTfOxjIJBB-bRuzVpKoLB1sCXJjAMy6Np3zl0LFClqavd2a51z0fAH8dxZXs1Wp')



# Search for Drake and attempt to retrieve all songs
# The `max_songs` parameter is set to None to try and get all songs
# Note: This may take a long time and can be subject to rate limiting
artists = ["Drake", "Lil Wayne", "Migos"]
for p in artists:
    artist = genius.search_artist(p, max_songs=2)
    
    # Loop through each song in the artist object and print the lyrics
    for song in artist.songs:
        print(song.title)
        print(song.lyrics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Replace 'your_token_here' with the token you obtained from Genius
# ----> 2 genius = Genius('stTfOxjIJBB-bRuzVpKoLB1sCXJjAMy6Np3zl0LFClqavd2a51z0fAH8dxZXs1Wp')
#       6 # Search for Drake and attempt to retrieve all songs
#       7 # The `max_songs` parameter is set to None to try and get all songs
#       8 # Note: This may take a long time and can be subject to rate limiting
#       9 artists = ["Drake", "Lil Wayne", "Migos"]
#
# NameError: name 'Genius' is not defined

# %% [markdown]
# ### Things noted after initial examination.
#
# 1. Last line is something like xxxxxx1234Embed
# 2. First line is usually bullshit, shoulbe figure out a way using regex and clean up.
# 3. There are different verses (like [Intro], [Outro])

# %% [markdown]
# ### 3. Data Cleaning

# %%
lyrics_df["Rhyme pairs"] = lyrics_df.apply(annotator.annotate_rhyme_pairs, axis=1)
    # Filter out poems without rhyme pairs
    lyrics_df = lyrics_df[lyrics_df["Rhyme pairs"].apply(lambda x: len(x)) > 0]

# %%
# Add the parent directory to the system path
sys.path.append(os.path.abspath('...'))

# %%
top30k= pd.read_csv("/Users/liqingyang/Documents/GitHub/nlp_project/data/lyrics_dataset_raw_sample.csv")
# Assuming top30k is your DataFrame and 'lyrics' is the column to be processed
square_brackets = r'\[.*?\]\n'
parenthesis = r'\(.*?\)'
no_punc = r'(?<=[\w\s])[!"#$%&\'*+,-./:;<=>?@\[\\\]^_`{|}~]+(?=\n)'
extra_line = r'\n\n+'
white_space = r' \n'


top30k['Content'] = (top30k['lyrics'].str.replace(square_brackets, '', regex=True)
                  .str.lstrip('\n')
                  .str.replace(no_punc, '', regex=True)
                  .str.replace(extra_line, '\n', regex=True)                  
                  .str.replace(parenthesis, '', regex=True)
                  .str.replace(white_space, '\n', regex=True))

# %%
import sys

# Path to the common base directory
base_dir = '/Users/liqingyang/Documents/GitHub/nlp_project/data/'

# Add the base directory to the system path
sys.path.append(base_dir)
# Path to the directory which should be the current working directory
new_working_directory = '/Users/liqingyang/Documents/GitHub/nlp_project/'

# Change the current working directory
os.chdir(new_working_directory)

# Now you can import and use your Annotator class as expected
from data.processing.cmu_pronuncing_dict.annotator import Annotator

# %%
annotator = Annotator();
top30k["Rhyme pairs"] = top30k.apply(annotator.annotate_rhyme_pairs, axis=1)
    # Filter out poems without rhyme pairs
top30k = top30k[top30k["Rhyme pairs"].apply(lambda x: len(x)) > 0]

# %%
def extract_and_pair_lyrics(row):
    """
    Extracts lyrics from one column and pairs them based on indices in another column.

    Args:
    row (pd.Series): A row of the DataFrame.

    Returns:
    list of tuples: Paired lyrics.
    """
    lyrics = row['lyrics_column']  # Adjust 'lyrics_column' to your DataFrame's column name
    selected_indices = row['Rhyme pairs']   # Adjust 'indices_column' to your DataFrame's column name
    paired_lyrics = [(lyrics[i[0]], lyrics[i[1]]) for i in selected_indices]

    return paired_lyrics

## Lyrics column consists of lyrics in list
top30k['lyrics_column'] = top30k['Content'].str.split('\n')
top30k['paired_lyrics'] = top30k.apply(extract_and_pair_lyrics, axis=1)

# %%
top30k.iloc[0, -1]
# Out:
# [('Bomaye, Killa Cam, my Lord',
#   'Still the man with the pan, scrilla, fam, on board'),
#  ("Doggy, I'm from the land of grind, pan-pan: gram or dime",
#   'Not toes or MC when I say "hammer time'),
#  ('Them niggas knew we bang', 'Stood out like Pootie Tang'),
#  ('That when the toolie sing', 'Came from that movie ring'),
#  ('Came from that movie ring', 'Flapjack, ooh he bring'),
#  ('Flapjack, ooh he bring', 'Clack-clack, "ooh he ring'),
#  ('Flapjack, ooh he bring', 'Bad rap, cuties cling'),
#  ('Clack-clack, "ooh he ring', 'Bad rap, cuties cling'),
#  ('Bad rap, cuties cling', "I'm the sushi king"),
#  ("And I'ma keep ya fresh", 'Let the fish eat ya flesh'),
#  ("That's how it usually ends", 'Tell her and her groupie friends'),
#  ("Bird's-eye view", 'Bird gangs, it was birds I flew'),
#  ('Bird gangs, it was birds I flew', 'And word I blew off herb I grew'),
#  ('I would serve on stoops', 'Now swerve in coupes')]

# %%
all_rhymed = top30k.paired_lyrics.to_list()

# %%
all_rhymed[0][0][0]
# Out:
# 'Bomaye, Killa Cam, my Lord'

# %%
all_rhymed[0]
# Out:
# [('Bomaye, Killa Cam, my Lord',
#   'Still the man with the pan, scrilla, fam, on board'),
#  ("Doggy, I'm from the land of grind, pan-pan: gram or dime",
#   'Not toes or MC when I say "hammer time'),
#  ('Them niggas knew we bang', 'Stood out like Pootie Tang'),
#  ('That when the toolie sing', 'Came from that movie ring'),
#  ('Came from that movie ring', 'Flapjack, ooh he bring'),
#  ('Flapjack, ooh he bring', 'Clack-clack, "ooh he ring'),
#  ('Flapjack, ooh he bring', 'Bad rap, cuties cling'),
#  ('Clack-clack, "ooh he ring', 'Bad rap, cuties cling'),
#  ('Bad rap, cuties cling', "I'm the sushi king"),
#  ("And I'ma keep ya fresh", 'Let the fish eat ya flesh'),
#  ("That's how it usually ends", 'Tell her and her groupie friends'),
#  ("Bird's-eye view", 'Bird gangs, it was birds I flew'),
#  ('Bird gangs, it was birds I flew', 'And word I blew off herb I grew'),
#  ('I would serve on stoops', 'Now swerve in coupes')]

# %%
all_rhymed
# Out:
# [[('Bomaye, Killa Cam, my Lord',
#    'Still the man with the pan, scrilla, fam, on board'),
#   ("Doggy, I'm from the land of grind, pan-pan: gram or dime",
#    'Not toes or MC when I say "hammer time'),
#   ('Them niggas knew we bang', 'Stood out like Pootie Tang'),
#   ('That when the toolie sing', 'Came from that movie ring'),
#   ('Came from that movie ring', 'Flapjack, ooh he bring'),
#   ('Flapjack, ooh he bring', 'Clack-clack, "ooh he ring'),
#   ('Flapjack, ooh he bring', 'Bad rap, cuties cling'),
#   ('Clack-clack, "ooh he ring', 'Bad rap, cuties cling'),
#   ('Bad rap, cuties cling', "I'm the sushi king"),
#   ("And I'ma keep ya fresh", 'Let the fish eat ya flesh'),
#   ("That's how it usually ends", 'Tell her and her groupie friends'),
#   ("Bird's-eye view", 'Bird gangs, it was birds I flew'),
#   ('Bird gangs, it was birds I flew', 'And word I blew off herb I grew'),
#   ('I would serve on stoops', 'Now swerve in coupes')],
# ...

# %%
songs = [i for i in all_rhymed]
lines = [j for j in i for i in songs]

# %%
# Extracting all first elements of the tuples
first_elements = [elem[0] for sublist in songs for elem in sublist]

# Extracting all second elements of the tuples
second_elements = [elem[1] for sublist in songs for elem in sublist]

# %%
rhymed = pd.DataFrame({'first_line': first_elements, 'next_line': second_elements})

# %%
rhymed.to_csv("/Users/liqingyang/Documents/GitHub/nlp_project/data/lyrics_rhyming_pairs.csv")

# %%
for i in range(0, len(flat_data) - sequence_length):
    input_sequences.append(flat_data[i:i + sequence_length])
    target_sequences.append(flat_data[i + sequence_length])
# Out:
#                                               first_line  \
# 0                             Bomaye, Killa Cam, my Lord
# 1      Doggy, I'm from the land of grind, pan-pan: gr...
# 2                               Them niggas knew we bang
# 3                              That when the toolie sing
# 4                              Came from that movie ring
# ...                                                  ...
# 87067                            Follow this, model this
# 87068  It don't matter but nobody take a day here to ...
# 87069        And you'll never get all that you've earned
# 87070             Only way that we ever gon' get to rise
# 87071                No love? Fuck it, then let's battle
#
#                                                next_line
# 0      Still the man with the pan, scrilla, fam, on b...
# 1                 Not toes or MC when I say "hammer time
# 2                             Stood out like Pootie Tang
# ...
