# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from numpy import array
import sys
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers import Bidirectional
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from keras.preprocessing.text import Tokenizer
#       6 from keras.preprocessing.sequence import pad_sequences
#       7 from keras.models import Sequential
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import _tf_keras
#       9 from keras import activations
#      10 from keras import applications
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/_tf_keras/__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/_tf_keras/keras/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import activations
#       9 from keras import applications
#      10 from keras import callbacks
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/activations/__init__.py:11
#       9 from keras.src.activations import get
#      10 from keras.src.activations import serialize
# ---> 11 from keras.src.activations.activations import elu
#      12 from keras.src.activations.activations import exponential
#      13 from keras.src.activations.activations import gelu
#
# ModuleNotFoundError: No module named 'keras.src.activations.activations'; 'keras.src.activations' is not a package

# %%
pip uninstall keras
# Out:
# Found existing installation: keras 2.15.0
# Uninstalling keras-2.15.0:
#   Would remove:
#     /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras-2.15.0.dist-info/*
#     /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 import keras
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import _tf_keras
#       9 from keras import activations
#      10 from keras import applications
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/_tf_keras/__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/_tf_keras/keras/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import activations
#       9 from keras import applications
#      10 from keras import callbacks
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/activations/__init__.py:11
#       9 from keras.src.activations import get
#      10 from keras.src.activations import serialize
# ---> 11 from keras.src.activations.activations import elu
#      12 from keras.src.activations.activations import exponential
#      13 from keras.src.activations.activations import gelu
#
# ModuleNotFoundError: No module named 'keras.src.activations.activations'; 'keras.src.activations' is not a package

# %%
import os
print(os.getcwd())
# Out:
# /Users/liqingyang/Documents/GitHub/nlp_project/data/lyrics/pre_processing_for_lstm
# Untitled.ipynb
# .ipynb_checkpoints

# %%
for item in os.listdir(os.getcwd()):
    print(item)
# Out:
# Untitled.ipynb
# .ipynb_checkpoints

# %%
import sys
print(sys.path)
# Out:
# ['/Users/liqingyang/Documents/GitHub/nlp_project/data/lyrics/pre_processing_for_lstm', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python311.zip', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload', '', '/Users/liqingyang/Library/Python/3.11/lib/python/site-packages', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages']

# %%
# !python3 --version

# To check the Python installation path
# !which python3
# Out:
# Python 3.11.4
# /Library/Frameworks/Python.framework/Versions/3.11/bin/python3

# %%
import site
import tensorflow


print("TensorFlow location:", tensorflow.__file__)

print("Site-packages location:", site.getsitepackages())
# Out:
# TensorFlow location: /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/__init__.py
# Site-packages location: ['/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages']
